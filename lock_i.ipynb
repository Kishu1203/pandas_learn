# %%
import pandas as pd


df = pd.read_csv('./data/Netflix Dataset.csv')
df.head(5)  # it gives the first 5 rows of the data
# Out:
#    Show_Id Category  Title              Director  \
# 0       s1  TV Show     3%                   NaN
# 1       s2    Movie  07:19     Jorge Michel Grau
# 2       s3    Movie  23:59          Gilbert Chan
# 3       s4    Movie      9           Shane Acker
# 4       s5    Movie     21        Robert Luketic
# 5       s6  TV Show     46           Serdar Akar
# 6       s7    Movie    122       Yasir Al Yasiri
# 7       s8    Movie    187        Kevin Reynolds
# 8       s9    Movie    706         Shravan Kumar
# 9      s10    Movie   1920          Vikram Bhatt
# 10     s11    Movie   1922          Zak Hilditch
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
# 13     s14    Movie  2,215   Nottapon Boonprakob
# 14     s15    Movie   3022            John Suits
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# ...

# %%
'''
#loc includes the last index
df.loc[0:10,['Title','Cast','Rating','Director']] # it gives the Title, Genre and Rating columns of rows from index 0 to 10
df.loc[0:5,'Title':'Type'] # it gives the Title, Genre and Rating columns of rows from index 0 to 5
df.loc[:,'Title'] == '3%' # it gives the Title column of all rows where the Title is '3%'(Provides boolean series)

# iloc excludes the last index
df.iloc[0:10,0:10] # it gives the first 10 rows and first 10 columns of the data
df.iloc[:5,[0,2,3,5]]# it gives the first 5 rows and 1st, 3rd, 4th and 6th columns of the data
'''
# Out:
# "\n#loc includes the last index\ndf.loc[0:10,['Title','Cast','Rating','Director']] # it gives the Title, Genre and Rating columns of rows from index 0 to 10\ndf.loc[0:5,'Title':'Type'] # it gives the Title, Genre and Rating columns of rows from index 0 to 5\ndf.loc[:,'Title'] == '3%' # it gives the Title column of all rows where the Title is '3%'(Provides boolean series)\n\n# iloc excludes the last index\ndf.iloc[0:10,0:10] # it gives the first 10 rows and first 10 columns of the data\ndf.iloc[:5,[0,2,3,5]]# it gives the first 5 rows and 1st, 3rd, 4th and 6th columns of the data\n"

# %%
'''
# searching for specific values
df.loc[df['Title'] == '3%',['Title','Cast','Rating','Director']] # it gives the Title, Genre and Rating columns of rows where the Title is '3%'

# Setting values
df.loc[df['Title'] == '3%','Rating'] = 9.0 # it sets the Rating of the rows where the Title is '3%' to 9.0
'''
# Out:
# "\n# searching for specific values\ndf.loc[df['Title'] == '3%',['Title','Cast','Rating','Director']] # it gives the Title, Genre and Rating columns of rows where the Title is '3%'\n\n# Setting values\ndf.loc[df['Title'] == '3%','Rating'] = 9.0 # it sets the Rating of the rows where the Title is '3%' to 9.0\n"

# %%
'''
# Additional operations
# and conditions
df[(df['Category']=='Movie')&(df['Title']=='9')] # it gives the rows where Category is 'Movie' and Title is '9'

# OR condition
df[(df['Category']=='Movie') | (df['Category']=='TV Show')].head(10) # it gives the first 10 rows where Category is either 'Movie' or 'TV Show'

# NOT condition
df[~(df['Category'] == 'Movie') & (df['Country'] == 'United States')].head(10) # it gives the first 10 rows where Category is not 'Movie' and Country is 'United States'

'''
# Out:
# "\n# Additional operations\n# and conditions\ndf[(df['Category']=='Movie')&(df['Title']=='9')] # it gives the rows where Category is 'Movie' and Title is '9'\n\n# OR condition\ndf[(df['Category']=='Movie') | (df['Category']=='TV Show')].head(10) # it gives the first 10 rows where Category is either 'Movie' or 'TV Show'\n\n# NOT condition\ndf[~(df['Category'] == 'Movie') & (df['Country'] == 'United States')].head(10) # it gives the first 10 rows where Category is not 'Movie' and Country is 'United States'\n\n"
